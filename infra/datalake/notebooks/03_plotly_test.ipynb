# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.DataFrame({
    "dia": ["L", "M", "X", "J", "V"],
    "valor": [10, 14, 8, 17, 13]
})

# %%
px.line(df, x="dia", y="valor", title="Plotly OK")
